# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/pranjal27bhardwaj/Desktop/Corona main/italy_total.csv")

# %%
data
# Out:
#           date  hospitalized_with_symptoms  intensive_care  \
# 0   2020-02-24                         101              26
# 1   2020-02-25                         114              35
# 2   2020-02-26                         128              36
# 3   2020-02-27                         248              56
# 4   2020-02-28                         345              64
# ..         ...                         ...             ...
# 77  2020-05-11                       13539             999
# 78  2020-05-12                       12865             952
# 79  2020-05-13                       12172             893
# 80  2020-05-14                       11453             855
# 81  2020-05-15                       10792             808
#
#     total_hospitalized  home_confinement  cumulative_positive_cases  \
# 0                  127                94                        221
# 1                  150               162                        311
# ...

# %%
data.head(10)
# Out:
#          date  hospitalized_with_symptoms  intensive_care  total_hospitalized  \
# 0  2020-02-24                         101              26                 127
# 1  2020-02-25                         114              35                 150
# 2  2020-02-26                         128              36                 164
# 3  2020-02-27                         248              56                 304
# 4  2020-02-28                         345              64                 409
# 5  2020-02-29                         401             105                 506
# 6  2020-03-01                         639             140                 779
# 7  2020-03-02                         742             166                 908
# 8  2020-03-03                        1034             229                1263
# 9  2020-03-04                        1346             295                1641
#
#    home_confinement  cumulative_positive_cases  daily_positive_cases  \
# ...

# %%
data.columns
# Out:
# Index(['date', 'hospitalized_with_symptoms', 'intensive_care',
#        'total_hospitalized', 'home_confinement', 'cumulative_positive_cases',
#        'daily_positive_cases', 'recovered', 'death', 'cumulative_cases',
#        'total_tests', 'total_people_tested'],
#       dtype='object')

# %%
data.tail()
# Out:
#           date  hospitalized_with_symptoms  intensive_care  \
# 77  2020-05-11                       13539             999
# 78  2020-05-12                       12865             952
# 79  2020-05-13                       12172             893
# 80  2020-05-14                       11453             855
# 81  2020-05-15                       10792             808
#
#     total_hospitalized  home_confinement  cumulative_positive_cases  \
# 77               14538             67950                      82488
# 78               13817             67449                      81266
# 79               13065             65392                      78457
# 80               12308             64132                      76440
# 81               11600             60470                      72070
#
#     daily_positive_cases  recovered  death  cumulative_cases  total_tests  \
# 77                  -836     106587  30739            219814      2606652
# ...

# %%
data.describe()
# Out:
#        hospitalized_with_symptoms  intensive_care  total_hospitalized  \
# count                   82.000000       82.000000           82.000000
# mean                 16866.646341     2061.524390        18928.182927
# std                   9772.029606     1293.449892        10988.350581
# min                    101.000000       26.000000          127.000000
# 25%                   9945.250000     1006.000000        11401.250000
# 50%                  17638.500000     1982.500000        19495.000000
# 75%                  25968.250000     3246.000000        29470.250000
# max                  29010.000000     4068.000000        33004.000000
#
#        home_confinement  cumulative_positive_cases  daily_positive_cases  \
# count         82.000000                  82.000000             82.000000
# mean       45650.829268               64579.000000            876.207317
# std        32059.408032               40314.941729           2131.599027
# ...

# %%
data.isnull().sum()
# Out:
# date                           0
# hospitalized_with_symptoms     0
# intensive_care                 0
# total_hospitalized             0
# home_confinement               0
# cumulative_positive_cases      0
# daily_positive_cases           0
# recovered                      0
# death                          0
# cumulative_cases               0
# total_tests                    0
# total_people_tested           55
# dtype: int64

# %% [markdown]
# # Relating the variables with scatterplots

# %%
sns.relplot(x="total_people_tested", y="recovered", data=data)

# %%
sns.relplot(x="death", y="recovered", data=data)

# %%
sns.relplot(x="hospitalized_with_symptoms", y="total_hospitalized", hue="recovered", data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x = 'total_people_tested', y = 'home_confinement', kind = 'line', data=data)

# %%
sns.catplot(x='recovered', y='total_hospitalized', data=data)
